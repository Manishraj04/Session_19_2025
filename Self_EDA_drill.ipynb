# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as scn
import os

# %%
old_dir=os.getcwd()
new_dir='seaborn_bank_file'
new_dir=os.path.join(old_dir,new_dir)
os.makedirs(new_dir)

# %%
path=r'C:\Users\manish\Datafile\bank.csv'
pd.read_csv(path,sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
path=r'C:\Users\manish\Datafile\bank.csv'
df=pd.read_csv(path,sep=';')
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
types=dict(df.dtypes)

# %%
cat_col=[key for key,values in types.items() if values=='object']
num_col=[key for key,values in types.items() if values!='object']

# %%
df['job'].value_counts()
# Out:
# job
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: count, dtype: int64

# %%
cmd=df['job'].value_counts()
x=cmd.keys()
y=cmd.values
plt.pie(y,labels=x,
       startangle=90);

# %%
old_dir=os.getcwd()
new_fol='Pie_char_bank'
new_dir1=os.path.join(old_dir,new_fol)
os.makedirs(new_dir1)

# %%
for i in cat_col:
    cnf=df[i].value_counts()
    keys=cnf.keys()
    values=cnf.values
    dff=plt.pie(values,labels=keys,startangle=90)
    plt.title(f'{i}__name')
    plt.savefig(f'{new_dir1}\\{i}_.jpg')

# %%
cf=df['job'].value_counts()
cf.plot(kind='bar')
# Out:
# <Axes: xlabel='job'>

# %%
old_dir=os.getcwd()
new_f1='one_shot_plt'
new_dir2=os.path.join(old_dir,new_f1)
os.makedirs(new_dir2)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[71], line 4
#       2 new_f1='one_shot_plt'
#       3 new_dir2=os.path.join(old_dir,new_f1)
# ----> 4 os.makedirs(new_dir2)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\manish\\Documents\\naresh it\\statistic\\one_shot_plt'

# %%
for i in cat_col:
    cnf=df[i].value_counts()
    cnf.plot(kind='bar')
    plt.title(f'{i}_name')
    plt.savefig(f'{new_dir2}\\{i}.jpg')

# %%
cnd=df['marital'].value_counts()
cnd.plot(kind='bar');
